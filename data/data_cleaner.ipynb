# %%
import pandas as pd

df = pd.read_csv('../data/raw_hotels.csv')
df.head()
# Out:
#                    Hotel Name Location County or Region Country  \
# 0  Muthu Silver Springs Hotel  Nairobi   Nairobi County   Kenya
# 1               Olive Gardens  Nairobi   Nairobi County   Kenya
# 2        Nairobi Serena Hotel  Nairobi   Nairobi County   Kenya
# 3            High Point Hotel  Nairobi   Nairobi County   Kenya
# 4        Southern Sun Mayfair  Nairobi   Nairobi County   Kenya
#
#              Hotel Description    Price Range Amenities  Room Types  Rating  \
# 0  A hotel located in Nairobi.  Check website       NaN         NaN     NaN
# 1  A hotel located in Nairobi.  Check website       NaN         NaN     NaN
# 2  A hotel located in Nairobi.  Check website       NaN         NaN     NaN
# 3  A hotel located in Nairobi.  Check website       NaN         NaN     NaN
# 4  A hotel located in Nairobi.  Check website       NaN         NaN     NaN
#
#    Review Summary  Nearby Attractions Hotel Category  \
# 0             NaN                 NaN        Unrated
# ...

# %%
df.isnull().sum()
# Out:
# Hotel Name                0
# Location                  0
# County or Region          0
# Country                   0
# Hotel Description         0
# Price Range               0
# Amenities              1260
# Room Types             1459
# Rating                 1459
# Review Summary         1459
# Nearby Attractions     1459
# Hotel Category            0
# Contact Information     652
# Website URL            1252
# Image URL              1459
# Source URL                0
# dtype: int64
